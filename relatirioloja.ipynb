# %%
# !pip install streamlit
# !pip install plotly
# !pip install pandas
# !pip install requests

# %%
import streamlit as st
import requests
import pandas as pd
import plotly.express as px

# %%
url = 'https://labdados.com/produtos'
response = requests.get(url)
dados = pd.DataFrame.from_dict(response.json())

# %%
url = 'https://labdados.com/produtos'
response = requests.get(url)
dados = pd.DataFrame.from_dict(response.json())

dados
# Out:
#                        Produto   Categoria do Produto   Preço      Frete  \
# 0          Modelagem preditiva                 livros   92.45   5.609697
# 1     Iniciando em programação                 livros   43.84   0.000000
# 2                     Pandeiro  instrumentos musicais   87.18   2.226512
# 3               Corda de pular        esporte e lazer   13.65   1.257926
# 4               Dinossauro Rex             brinquedos   28.32   2.039059
# ...                        ...                    ...     ...        ...
# 9430                Impressora            eletronicos  472.77  25.456706
# 9431   Dashboards com Power BI                 livros   54.85   3.451702
# 9432           Cubo mágico 8x8             brinquedos   19.74   0.000000
# 9433                  Faqueiro  utilidades domesticas   52.49   0.000000
# 9434               Micro-ondas       eletrodomesticos  711.30  35.459024
#
#      Data da Compra          Vendedor Local da compra  Avaliação da compra  \
# ...

# %%
vendas_estados = dados.groupby('Local da compra').count()
vendas_estados = dados.drop_duplicates(subset = 'Local da compra')[['Local da compra', 'lat', 'lon']].merge(vendas_estados, left_on = 'Local da compra', right_index = True).sort_values('Preço', ascending = False)
vendas_estados
# Out:
#      Local da compra  lat_x  lon_x  Produto  Categoria do Produto  Preço  \
# 1                 SP -22.19 -48.79     3943                  3943   3943
# 2                 RJ -22.25 -42.66     1212                  1212   1212
# 7                 MG -18.10 -44.38     1102                  1102   1102
# 15                RS -30.17 -53.50      534                   534    534
# 16                PR -24.89 -51.55      473                   473    473
# 43                SC -27.45 -50.95      346                   346    346
# 0                 BA -13.29 -41.71      310                   310    310
# 73                DF -15.83 -47.86      242                   242    242
# 189               GO -15.98 -49.86      186                   186    186
# 57                PE  -8.38 -37.86      181                   181    181
# 6                 ES -19.19 -40.34      171                   171    171
# 84                CE  -5.20 -39.53      151                   151    151
# ...

# %%
vendas_mensal = pd.DataFrame(dados.set_index('Data da Compra').groupby(pd.Grouper(freq = 'ME'))['Preço'].count()).reset_index()
vendas_mensal['Ano'] = vendas_mensal['Data da Compra'].dt.year
vendas_mensal['Mes'] = vendas_mensal['Data da Compra'].dt.month_name()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 vendas_mensal = pd.DataFrame(dados.set_index('Data da Compra').groupby(pd.Grouper(freq = 'ME'))['Preço'].count()).reset_index()
#       2 vendas_mensal['Ano'] = vendas_mensal['Data da Compra'].dt.year
#       3 vendas_mensal['Mes'] = vendas_mensal['Data da Compra'].dt.month_name()
#
# File ~/venv/lib/python3.12/site-packages/pandas/core/frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
# ...

# %%
vendas_mensal = pd.DataFrame(dados.set_index('Data da Compra').groupby(pd.Grouper(freq = 'ME'))['Preço'].count()).reset_index()
vendas_mensal['Ano'] = vendas_mensal['Data da Compra'].dt.year
vendas_mensal['Mes'] = vendas_mensal['Data da Compra'].dt.month_name()

# %%
vendas_mensal = dados.set_index('Data da Compra').groupby(pd.Grouper(freq = 'ME'))['Preço'].count().reset_index()
vendas_mensal['Ano'] = vendas_mensal['Data da Compra'].dt.year
vendas_mensal['Mes'] = vendas_mensal['Data da Compra'].dt.month_name()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 vendas_mensal = dados.set_index('Data da Compra').groupby(pd.Grouper(freq = 'ME'))['Preço'].count().reset_index()
#       2 vendas_mensal['Ano'] = vendas_mensal['Data da Compra'].dt.year
#       3 vendas_mensal['Mes'] = vendas_mensal['Data da Compra'].dt.month_name()
#
# File ~/venv/lib/python3.12/site-packages/pandas/core/frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
# ...

# %%
lista_ob = list(dados.select_dtypes(include='object').columns)
lista_ob
# Out:
# ['Produto',
#  'Categoria do Produto',
#  'Data da Compra',
#  'Vendedor',
#  'Local da compra',
#  'Tipo de pagamento']

# %%
lista_ob.remove( 'Data da Compra')
lista_ob.remove( 'Produto')

# %%
lista_ob
# Out:
# ['Categoria do Produto', 'Vendedor', 'Local da compra', 'Tipo de pagamento']

# %%
for i in lista_ob:
     print(dados[i].unique())
# Out:
# ['livros' 'instrumentos musicais' 'esporte e lazer' 'brinquedos'
#  'utilidades domesticas' 'eletrodomesticos' 'eletronicos' 'moveis']
# ['Thiago Silva' 'Mariana Ferreira' 'Camila Ribeiro' 'Juliana Costa'
#  'João Souza' 'Beatriz Moraes' 'Pedro Gomes' 'Isabella Pereira'
#  'Bruno Rodrigues' 'Rafael Costa' 'Bianca Santos' 'Larissa Alves'
#  'Felipe Santos' 'Lucas Oliveira']
# ['BA' 'SP' 'RJ' 'ES' 'MG' 'RS' 'PR' 'SC' 'AL' 'PE' 'MS' 'DF' 'PB' 'CE'
#  'PA' 'MA' 'RO' 'MT' 'GO' 'TO' 'RN' 'SE' 'PI' 'AM' 'AC' 'AP' 'RR']
# ['cartao_credito' 'boleto' 'cartao_debito' 'cupom']

# %%
dados['Avaliação da compra']
# Out:
# 0       1
# 1       5
# 2       4
# 3       4
# 4       1
#        ..
# 9430    4
# 9431    5
# 9432    5
# 9433    4
# 9434    5
# Name: Avaliação da compra, Length: 9435, dtype: int64
